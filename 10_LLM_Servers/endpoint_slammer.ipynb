# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# **In theory…**
#
# A 2012 study by a group of *scientist-peeps* at the Anthropo‑Logistics Institute (yes, that’s a real institute, if you count the university’s “wildlife & your‑average‑person” department) found that a wood‑chuck (aka *ground‑hog*) could chuck approximately **44.7 kg** of wood per shaking session, assuming:
#
# - The chuck can leap 0.5 m each time,
# - It uses a specialized “wood‑hand” claw,
# - And the wood is straight‑cut, 4 mm thick.
#
# Multiplying that over a day at a brisk 20 h–on‑the‑job‑rate gives roughly **893 kg** (≈ 1.96 imperial‑tons). That’s about the mass of a **Toyota Hilux**.
#
# ---
#
# ### Why the number matters:
#
# - **Home‑renovation budgets**: A single chuck can move a cabin‑sized living‑room in just under 12 hours.
# - **Forest‑management policies**: If every chuck in a 1 km² of temperate forest could keep up this pace, you’d have a wood‑cucking ecosystem that could supply the local lumber supply in a matter of weeks.
#
# ---
#
# ## Disclaimer
#
# - **Humor note**: The “study” is largely tongue‑in‑cheek; real data on chucking ability is actually no more forthcoming than the exact answer to “how many words are in Hamlet.”
# - **All measurements are figurative**: Wood‑chucks are not known to literally chuck wood in the wild, and it is certainly absurd to let a large number of them try to stack timber.
#
# ---
#
# **Bottom line**: A wood‑chuck that can actually chuck wood would move about **900 kg** a day—enough to give a campfire and a pie a respectable carve. If you find yourself in the middle of a wood‑chuck’s chucking session, consider bringing them a donut. 🍩

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 13: A wood‑chuck would chuck as much wood as its little burrowin...
# Response 11: A classic reply is:
#
# > If a woodchuck could chuck wood, he’d...
# Response 22: A classic estimate is that a wood‑chuck would chuck **about ...
# Response 8: Sure thing! 🎶👷‍♂️
#
# > **“He would chuck**
# > **Infinite… unl...
# Response 1: It’s the classic tongue‑twister that never actually has a sc...
# Response 5: **Answer:**
# The classic tongue‑twister doesn’t have a defi...
# Response 24: A classic answer to the tongue‑twister is that a woodchuck w...
# Response 7: The classic tongue‑twister doesn’t have a definitive answer—...
# Response 14: **Answer (classic tongue‑twister)**
# > “A woodchuck would c...
# Response 16: The classic tongue‑twister is a bit of folklore rather than ...
# Response 15: That classic tongue‑twister is more a bit of folklore than a...
# Response 6: The classic tongue‑twister doesn’t have a single “right” ans...
# Response 19: **Because a woodchuck *has no thumbfingers to pack a saw‑bla...
# Response 17: That classic tongue‑twister has inspired more chuckles than ...
# Response 9: The classic tongue‑twister is intentionally playful and does...
# Response 23: **Quick answer:**
# About **700 **pounds** of wood** (roughl...
# Response 3: It turns out that the “wood‑chuck” story is just a tongue‑tw...
# Response 2: **Short answer:** Roughly **700 pounds** of wood—if a woodch...
# Response 12: ### The Classic Answer
#
# > **"As much wood as a wood‑chuck wo...
# Response 4: **Answer (with a classic twist):**
#
# A wood‑chuck would chuck...
# Response 21: **Short answer:**
# A wood‑chuck could chuck *about 700 poun...
# Response 10: How
#   [much] wood
#     could a [wood] chuck
#       [chuck] if ...
# Response 20: **Short answer:**
# A real‑life wood‑chuck (ground‑hog) woul...
# Response 18: I am no...
